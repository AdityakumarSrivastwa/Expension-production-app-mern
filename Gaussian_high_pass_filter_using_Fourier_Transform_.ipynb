# %% [markdown]
# <a href="https://colab.research.google.com/github/AdityakumarSrivastwa/Expension-production-app-mern/blob/main/Gaussian_high_pass_filter_using_Fourier_Transform_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
import numpy as np

# %%
from matplotlib import pyplot as plt

# %%
image = cv2.imread('/content/Image1.jpeg', 0)  # Load the image in grayscale

# %% [markdown]
# **# Step 4: Convert to Frequency Domain**

# %%
dft = cv2.dft(np.float32(image), flags=cv2.DFT_COMPLEX_OUTPUT)
dft_shift = np.fft.fftshift(dft)

# %% [markdown]
# **# Step 5: Create the Gaussian High-Pass Filter**

# %%
rows, cols = image.shape
crow, ccol = rows // 2, cols // 2
D0 = 30  # cutoff frequency
x, y = np.ogrid[:rows, :cols]
mask = 1 - np.exp(-((x - crow) ** 2 + (y - ccol) ** 2) / (2 * D0 ** 2))

# %%
mask = np.stack((mask, np.zeros_like(mask)), axis=2)

# %% [markdown]
# **# Step 6: Apply the Filter**

# %%
fshift = dft_shift * mask

# %% [markdown]
# **# Step 7: Inverse Transform**

# %%
f_ishift = np.fft.ifftshift(fshift)
img_back = cv2.idft(f_ishift)
img_back = cv2.magnitude(img_back[:, :, 0], img_back[:, :, 1])

# %% [markdown]
# **# Step 8: Display the Results**

# %%
plt.figure(figsize=(12, 6))
plt.subplot(121), plt.imshow(image, cmap='gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(img_back, cmap='gray')
plt.title('Gaussian High-Pass Filtered Image'), plt.xticks([]), plt.yticks([])
plt.show()
