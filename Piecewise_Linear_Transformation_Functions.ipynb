# %% [markdown]
# <a href="https://colab.research.google.com/github/AdityakumarSrivastwa/Expension-production-app-mern/blob/main/Piecewise_Linear_Transformation_Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
import numpy as np

# %%
from google.colab.patches import cv2_imshow

# %%
def pixelVal(pix, r1, s1, r2, s2):
    if (0 <= pix and pix <= r1):
        return (s1 / r1)*pix
    elif (r1 < pix and pix <= r2):
        return ((s2 - s1)/(r2 - r1)) * (pix - r1) + s1
    else:
        return ((255 - s2)/(255 - r2)) * (pix - r2) + s2

# %%
img = cv2.imread('/content/Image1.jpeg')

# %%
r1 = 70
s1 = 0
r2 = 140
s2 = 255

# %%
pixelVal_vec = np.vectorize(pixelVal)

# %%
contrast_stretched = pixelVal_vec(img, r1, s1, r2, s2)

# %%
combined_image = np.hstack((img,contrast_stretched))

# %%
cv2_imshow(combined_image)
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1280>
